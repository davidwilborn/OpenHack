# %%
from glob import glob
import pandas as pd
import numpy as np
import os
from PIL import Image
data_dir = 'gear_images'

# %%
labels = os.listdir(data_dir)
print(labels)
# Out:
# ['axes', 'boots', 'carabiners', 'crampons', 'gloves', 'hardshell_jackets', 'harnesses', 'helmets', 'insulated_jackets', 'pulleys', 'rope', 'tents']

# %%
for label in labels:
    files = (os.listdir(os.path.join(data_dir,label)))
    #data = np.asarray(Image.open(label+str(int(row[['id']]))+'.png'))
    #X_train.append(data)
    #y_train.append(int(row[['orientation']]))
# Out:
# ['100172.jpeg', '10036053x1012980_zm.jpeg', '10045714_zm.jpeg', '100937.jpeg', '100938.jpeg', '10101173x1012980_zm.jpeg', '10188438x1011898_zm.jpeg', '10189964_zm.jpeg', '10189970_zm.jpeg', '10189971_zm.jpeg', '10215531x1028317_zm.jpeg', '10258915x1152209_zm.jpeg', '10260981_zm.jpeg', '10260983_zm.jpeg', '10285571x1013345_zm.jpeg', '10285573x1013345_zm.jpeg', '10291030_zm.jpeg', '10291102_zm.jpeg', '10321075_zm.jpeg', '10331860x1078795_zm.jpeg', '10331871x1010938_zm.jpeg', '10347141x1152209_zm.jpeg', '10351594_zm.jpeg', '10351595_zm.jpeg', '10351608_zm.jpeg', '10353611_zm.jpeg', '10353612_zm.jpeg', '10353624_zm.jpeg', '10353625_zm.jpeg', '107254.jpeg', '113409.jpeg', '113410.jpeg', '1312778_000_main.jpg', '1312779_000_main.jpg', '1312786_004_main.jpg', '1312788_004_main.jpg', '1312790_004_main.jpg', '1312793_915_main.jpg', '1312794_000_main.jpg', '1312796_000_main.jpg', '1312797_000_main.jpg', '2022015_701_main.jpg', '2022022_004_main.jpg', '2022035_601_main.jpg', '2027570_007_main.j
# ...

# %%
for file in glob('test/*.png'):
    data = np.asarray(Image.open(file))
    X_test.append(data)

# %%
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train)
# Out:
# c:\users\lahulsta\appdata\local\continuum\anaconda3\envs\py36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
import random

# dimensions of our images.
img_width, img_height = 64, 64
num_classes=4
X_train = np.array(X_train)
X_test = np.array(X_test)
X_train = X_train.reshape(X_train.shape[0], img_width, img_height, 1)
X_test = X_test.reshape(X_test.shape[0], img_width, img_height, 1)
input_shape = (img_width, img_height, 1)
X_train = X_train/255
X_test = X_test/255

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# compile the model with a SGD/momentum optimizer
# and a very slow learning rate.
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.fit(np.array(X_train), np.array(y_train), validation_split=0.2, nb_epoch=10, batch_size=128, verbose=1)
# Out:
# c:\users\lahulsta\appdata\local\continuum\anaconda3\envs\py36\lib\site-packages\keras\models.py:942: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 16000 samples, validate on 4000 samples
# Epoch 1/10
# 16000/16000 [==============================] - 18s 1ms/step - loss: 0.2219 - acc: 0.9208 - val_loss: 0.0165 - val_acc: 0.9958
# Epoch 2/10
# 16000/16000 [==============================] - 17s 1ms/step - loss: 0.0259 - acc: 0.9946 - val_loss: 0.0107 - val_acc: 0.9980
# Epoch 3/10
# 16000/16000 [==============================] - 17s 1ms/step - loss: 0.0191 - acc: 0.9951 - val_loss: 0.0052 - val_acc: 0.9988
# Epoch 4/10
# 16000/16000 [==============================] - 22s 1ms/step - loss: 0.0115 - acc: 0.9968 - val_loss: 0.0047 - val_acc: 0.9988
# Epoch 5/10
# 16000/16000 [==============================] - 22s 1ms/step - loss: 0.0079 - acc: 0.9978 - val_loss: 0.0065 - val_acc: 0.9982
# Epoch 6/10
# ...

# %%
y_eval = model.predict(X_test)

# %%
df =  pd.DataFrame(list(zip(list(range(200000, 220000)),list(np.argmax(y_eval, axis =1)))), columns=['id', 'orientation'])
df.to_csv('submission.csv', index=False)
